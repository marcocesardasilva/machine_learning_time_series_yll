# %%
# importar bibliotecas
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Realizar conexão com o GCP
credentials = service_account.Credentials.from_service_account_file("../../keys/ml-na-saude-ed1fc3c1a83e.json")
client = bigquery.Client(credentials=credentials, project=credentials.project_id)

# %%
# Nome do projeto do GCP público
project_id = "basedosdados"
dataset_id = "br_ms_populacao"
table_id = "municipio"

# Construindo a referência da tabela pública
table_ref = f"{project_id}.{dataset_id}.{table_id}"

# %%
# Realizando uma consulta simples para a tabela pública
query = f"""
SELECT 
SAFE_CAST(ano AS INT64) ano,
SAFE_CAST(id_municipio AS STRING) id_municipio,
SAFE_CAST(sexo AS STRING) sexo,
SAFE_CAST(grupo_idade AS STRING) grupo_idade,
SAFE_CAST(populacao AS INT64) populacao
FROM basedosdados-staging.br_ms_populacao_staging.municipio AS t
"""

# %%
# Executando a consulta
query_job = client.query(query).to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:42
#      41 try:
# ---> 42     import db_dtypes  # type: ignore
#      44     date_dtype_name = db_dtypes.DateDtype.name
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Executando a consulta
# ----> 2 query_job = client.query(query).to_dataframe()
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\job\query.py:2058, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype)
#    1851 """Return a pandas DataFrame from a QueryJob
#    1852
#    1853 Args:
#    (...)
#    2055         :mod:`shapely` library cannot be imported.
#    2056 """
#    2057 query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
# -> 2058 return query_result.to_dataframe(
#    2059     bqstorage_client=bqstorage_client,
#    2060     dtypes=dtypes,
#    2061     progress_bar_type=progress_bar_type,
#    2062     create_bqstorage_client=create_bqstorage_client,
#    2063     geography_as_object=geography_as_object,
#    2064     bool_dtype=bool_dtype,
#    2065     int_dtype=int_dtype,
#    2066     float_dtype=float_dtype,
#    2067     string_dtype=string_dtype,
#    2068     date_dtype=date_dtype,
#    2069     datetime_dtype=datetime_dtype,
#    2070     time_dtype=time_dtype,
#    2071     timestamp_dtype=timestamp_dtype,
#    2072     range_date_dtype=range_date_dtype,
#    2073     range_datetime_dtype=range_datetime_dtype,
#    2074     range_timestamp_dtype=range_timestamp_dtype,
#    2075 )
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\table.py:2287, in RowIterator.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype)
#    2052 def to_dataframe(
#    2053     self,
#    2054     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    2073     ] = DefaultPandasDTypes.RANGE_TIMESTAMP_DTYPE,
#    2074 ) -> "pandas.DataFrame":
#    2075     """Create a pandas DataFrame by loading all pages of a query.
#    2076
#    2077     Args:
#    (...)
#    2285
#    2286     """
# -> 2287     _pandas_helpers.verify_pandas_imports()
#    2289     if geography_as_object and shapely is None:
#    2290         raise ValueError(_NO_SHAPELY_ERROR)
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:1026, in verify_pandas_imports()
#    1024     raise ValueError(_NO_PANDAS_ERROR) from pandas_import_exception
#    1025 if db_dtypes is None:
# -> 1026     raise ValueError(_NO_DB_TYPES_ERROR) from db_dtypes_import_exception
#
# ValueError: Please install the 'db-dtypes' package to use this function.

# %%
consulta_sql = """SELECT * FROM `ml-na-saude.yll_por_obito.yll_por_obito`"""
df = client.query(consulta_sql).to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       2 results = query_job.result()
#       3 for row in results:
# ----> 4     print(f"Palavra: {row['word']}, Contagem: {row['word_count']}")
#
# File c:\Users\marco\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\table.py:1505, in Row.__getitem__(self, key)
#    1503     value = self._xxx_field_to_index.get(key)
#    1504     if value is None:
# -> 1505         raise KeyError("no row field {!r}".format(key))
#    1506     key = value
#    1507 return self._xxx_values[key]
#
# KeyError: "no row field 'word'"

# %%
import os
import pandas as pd
from dateutil.relativedelta import relativedelta

# caminho para a pasta onde estão os arquivos CSV
caminho_pasta = 'dados'
# lista com os dataframes já tratados
dfs = []
# Lista com os códigos de cid-10 pertencentes aos ICSAPS
COD_ICSAPS = ["A37","A36","A33","A34","A35","B26","B06","B05","A95","B16","G000","A170","A19","A150","A151","A152","A153","A160","A161","A162",
          "A154","A155","A156","A157","A158","A159","A163","A164","A165","A166","A167","A168","A169","A171","A172","A173","A174","A175","A176",
          "A177","A178","A179","A18","I00","I01","I02","A51","A52","A53","B50","B51","B52","B53","B54","B77","E86","A00","A01","A02","A03","A04",
          "A05","A06","A07","A08","A09","D50","E40","E41","E42","E43","E44","E45","E46","E50","E51","E52","E53","E54","E55","E56","E57","E58",
          "E59","E60","E61","E62","E63","E64","H66","J00","J01","J02","J03","J06","J31","J13","J14","J153","J154","J158","J159","J181","J45",
          "J46","J20","J21","J40","J41","J42","J43","J47","J44","I10","I11","I20","I50","J81","I63","I64","I65","I66","I67","I69","G45","G46",
          "E100","E101","E110","E111","E120","E121","E130","E131","E140","E141","E102","E103","E104","E105","E106","E107","E108","E112","E113",
          "E114","E115","E116","E117","E118","E122","E123","E124","E125","E126","E127","E128","E132","E133","E134","E135","E136","E137","E138",
          "E142","E143","E144","E145","E146","E147","E148","E109","E119","E129","E139","E149","G40","G41","N10","N11","N12","N30","N34","N390",
          "A46","L01","L02","L03","L04","L08","N70","N71","N72","N73","N75","N76","K25","K26","K27","K28","K920","K921","K922","O23","A50","P350"]

for arquivo in os.listdir(caminho_pasta):
    if arquivo.endswith('.csv'):
        # Ler o arquivo CSV com o pandas
        df = pd.read_csv(os.path.join(caminho_pasta, arquivo), delimiter=';', encoding='ISO-8859-1', low_memory=False)
        # Função lambda para analisar se é ou não icsaps
        df['icsaps'] = df['CAUSABAS'].apply(lambda x: 'Sim' if x in COD_ICSAPS else 'Não')
        # Manter apenas dados que são icsaps
        df = df[df['icsaps'] == 'Sim']
        # Realizar transformação das datas de nascimento e óbito
        df['DTOBITO'] = pd.to_datetime(df['DTOBITO'], format='%d%m%Y', errors='coerce')
        df['DTNASC'] = pd.to_datetime(df['DTNASC'], format='%d%m%Y', errors='coerce')
        # Excluir dados nulos para data de nascimento e de óbito
        df = df.dropna(subset=['DTNASC'])
        df = df.dropna(subset=['DTOBITO'])
        # Criar a coluna idade
        df['idade'] = df.apply(lambda row: relativedelta(row['DTOBITO'], row['DTNASC']).years, axis=1)
        # Criando a coluna 'ano_obito'
        df['ano_obito'] = df['DTOBITO'].dt.year.astype(float).astype(pd.Int64Dtype()).astype(str).where(df['DTOBITO'].notna())
        # Criando a coluna 'quadrimestre_obito' usando pd.cut()
        df['quad_obito'] = pd.cut(df['DTOBITO'].dt.month, bins=[1, 5, 9, 13], labels=[1, 2, 3], right=False)
        # Extrair os 6 primeiros dígitos da coluna CODMUNRES
        df['CODMUNRES'] = df['CODMUNRES'].astype(str).str.slice(stop=6)
        # Renomear colunas
        df = df.rename(columns={
            'DTOBITO': 'dt_obito',
            'DTNASC':'dt_nasc',
            'CAUSABAS':'cid10',
            'CODMUNRES':'cd_mun_res'
            })
        # Selecionar coluna desejadas
        df = df[["ano_obito","quad_obito","dt_obito","dt_nasc","idade","cid10","cd_mun_res"]]
        # adiciona o dataframe à lista de dataframes
        dfs.append(df)
# concatena os dataframes em um único dataframe final
df_group = pd.concat(dfs, ignore_index=True)

# %%
# exibe o dataframe final
df_group.head()
# Out:
#   ano_obito quad_obito   dt_obito    dt_nasc  idade cid10 icsaps cd_mun_res
# 0      2010          2 2010-05-30 1937-09-04     72   I64    Sim     120070
# 1      2010          2 2010-06-08 1916-12-04     93   I10    Sim     120040
# 2      2010          1 2010-02-20 1975-04-28     34   J81    Sim     120045
# 3      2010          1 2010-03-11 1915-10-12     94  E149    Sim     120040
# 4      2010          2 2010-05-14 1918-09-20     91   I10    Sim     120040

# %%
df_group.dtypes
# Out:
# ano_obito             object
# quad_obito          category
# dt_obito      datetime64[ns]
# dt_nasc       datetime64[ns]
# idade                  int64
# cid10                 object
# icsaps                object
# cd_mun_res            object
# dtype: object

# %%
df_group.columns
# Out:
# Index(['ano_obito', 'quad_obito', 'dt_obito', 'dt_nasc', 'idade', 'cid10',
#        'icsaps', 'cd_mun_res'],
#       dtype='object')

# %%
df_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755154 entries, 0 to 1755153
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ano_obito   object
#  1   quad_obito  category
#  2   dt_obito    datetime64[ns]
#  3   dt_nasc     datetime64[ns]
#  4   idade       int64
#  5   cid10       object
#  6   icsaps      object
#  7   cd_mun_res  object
# dtypes: category(1), datetime64[ns](2), int64(1), object(4)
# memory usage: 95.4+ MB

# %%
df_group.shape
# Out:
# (1755154, 8)

# %%
df_group.isna().sum()
# Out:
# ano_obito     0
# quad_obito    0
# dt_obito      0
# dt_nasc       0
# idade         0
# cid10         0
# icsaps        0
# cd_mun_res    0
# dtype: int64
